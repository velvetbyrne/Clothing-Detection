# %%
pip install ultralytics --user
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting ultralytics
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/a8/97/d6d2592ba629ab41e18aaba14a4d75a5b56c40398a1c0b9e5979317798d0/ultralytics-8.0.196-py3-none-any.whl.metadata
#   Using cached ultralytics-8.0.196-py3-none-any.whl.metadata (31 kB)
# ...
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/74/07/edce54779f5c3fe8ab8390eafad3d7c8190fce68f922a254ea77f4a94a99/torch-2.1.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.1.0-cp311-cp311-win_amd64.whl.metadata (25 kB)
# ...

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import os
import json
import cv2
import random 
import sklearn
import pybboxes as pbx
import pydot
import json
import tqdm
import shapely
import yaml
from shapely.geometry import Polygon
from matplotlib import pyplot as pl
from matplotlib import image as mpimg
# from ultralytics import YOLO

# %%
# Directory Initialization

#Training
training_image = "F:/UNI/Proposal Skripsi/deepfashion2_dataset/train/image"
training_annos = "F:/UNI/Proposal Skripsi/deepfashion2_dataset/train/annos"

#Validation
val_image = "F:/UNI/Proposal Skripsi/deepfashion2_dataset/validation/image"
val_annos = "F:/UNI/Proposal Skripsi/deepfashion2_dataset/validation/annos"

#Test
training_image = "F:/UNI/Proposal Skripsi/deepfashion2_dataset/test/image"

# %%
img_id = "000001"
image = mpimg.imread(f"F:/UNI/Proposal Skripsi/deepfashion2_dataset/train/image/{img_id}.jpg")
pl.imshow(image)
pl.show()

# %%
# train_annotation = os.listdir(training_annos)
# train_images = os.listdir(training_image)

# # for file in train_annotation:
# f = open(f"F:/UNI/Proposal Skripsi/deepfashion2_dataset/train/annos/000001.json")
# data = json.load(f)

# bound = data['item2']['bounding_box']
# catid = data['item2']['category_id']
# cat = data['item2']['category_name']
# segment = data['item2']['segmentation']

# segment = np.squeeze(segment)
# len_segment = len(segment)

# for current_segment in segment:
#     list_poly = []
#     for i in range(0, len(current_segment), 2):
#         list_poly.append((current_segment[i], current_segment[i+1]))
#     print(list_poly)

# # break

# f.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1565, in squeeze(a, axis)
#    1564 try:
# -> 1565     squeeze = a.squeeze
#    1566 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'squeeze'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 13
#      10 cat = data['item2']['category_name']
#      11 segment = data['item2']['segmentation']
# ---> 13 segment = np.squeeze(segment)
#      14 len_segment = len(segment)
#      16 for current_segment in segment:
#
# File <__array_function__ internals>:200, in squeeze(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1567, in squeeze(a, axis)
#    1565     squeeze = a.squeeze
# ...

# %%
train_annotation = os.listdir(training_annos)
train_images = os.listdir(training_image)

full = []
for i in range(1):
    f = open(f"F:/UNI/Proposal Skripsi/deepfashion2_dataset/train/annos/{train_annotation[i]}")
    img = cv2.imread(f"F:/UNI/Proposal Skripsi/deepfashion2_dataset/train/image/{train_images[i]}")
    data = json.load(f)
    
    bound = data['item1']['bounding_box']
    catid = data['item1']['category_id']
    cat = data['item1']['category_name']
    segment = data['item1']['segmentation']
    
    data_dict = bound, catid, cat
    full.append(data_dict)
    
    print(bound)
    print(catid)
    print(cat)
    print(segment)
    
# store all into one variable then write
# with open('output.yaml', 'w') as yaml_file:
#     yaml.dump(full, yaml_file)
# Out:
# [0, 29, 466, 622]
# 1
# short sleeve top
# [[257, 35, 261, 89, 228, 123, 137, 103, 45, 91, 1, 176, 0, 332, 47, 447, 151, 401, 141, 366, 129, 328, 141, 364, 219, 485, 274, 603, 401, 590, 467, 502, 442, 336, 369, 195, 348, 138, 363, 163, 372, 197, 433, 137, 396, 92, 341, 35, 257, 35], [1, 176, 0, 332, 47, 447, 151, 401, 141, 366, 129, 328, 1, 176], [348, 138, 363, 163, 372, 197, 433, 137, 396, 92, 341, 35, 348, 138]]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\BENJAM~1\AppData\Local\Temp/ipykernel_14780/2676041954.py in <module>
#       1 voc_bbox = bound
# ----> 2 pbx.convert_bbox(voc_bbox, from_type="voc", to_type="yolo", image_size=(624,468))
#
# D:\Anaconda3\lib\site-packages\pybboxes\functional.py in convert_bbox(bbox, from_type, to_type, image_size, return_values, **kwargs)
#      35         bbox = load_bbox(name=from_type, values=bbox, image_size=image_size, **kwargs)
#      36     source_to_target = getattr(bbox, f"to_{to_type}")
# ---> 37     target_bbox = source_to_target()
#      38     if return_values:
#      39         return target_bbox.values
#
# D:\Anaconda3\lib\site-packages\pybboxes\boxes\base.py in to_yolo(self, return_values)
#     145
#     146     def to_yolo(self, return_values: bool = False) -> Union[Tuple[int, int, int, int], "BaseBoundingBox"]:
# ...
