# %%
import pandas as pd
import numpy as np
import os
import json
import cv2
import random
import sklearn
import pydot
import tqdm
from datetime import datetime

from matplotlib import image as mpimg
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import yaml
import torch
from pathlib import Path

import ultralytics
from ultralytics import YOLO

# %%
directory_path = "D:/Skripsi/dataset/images/test"
image_list = []

if os.path.exists(directory_path):
    for filename in os.listdir(directory_path):
        if filename.endswith(".jpg") or filename.endswith(".jpeg"):
            image_list.append(filename)
else:
    print(f"The directory '{directory_path}' does not exist.")

# %%
model_path = "D:/Skripsi/Results/9-11-2023-50epch/weights/best.pt"
model = YOLO(model_path)

# Define path to directory containing images and videos for inference
source = "D:/Skripsi/dataset/images/test"

# Run inference on the source
results = model.predict(source, stream=True, augment=True)

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs
# Out:
# image 1/62629 D:\Skripsi\dataset\images\test\000001.jpg: 640x480 1 short sleeve top, 1 trousers, 440.5ms
# image 2/62629 D:\Skripsi\dataset\images\test\000002.jpg: 640x480 1 short sleeve top, 692.0ms
# image 3/62629 D:\Skripsi\dataset\images\test\000003.jpg: 640x480 1 short sleeve top, 1 skirt, 1015.3ms
# image 4/62629 D:\Skripsi\dataset\images\test\000004.jpg: 640x480 1 short sleeve top, 1 skirt, 1152.6ms
# image 5/62629 D:\Skripsi\dataset\images\test\000005.jpg: 640x480 1 long sleeve outwear, 1137.8ms
# image 6/62629 D:\Skripsi\dataset\images\test\000006.jpg: 640x480 1 short sleeve top, 1 skirt, 1202.7ms
# image 7/62629 D:\Skripsi\dataset\images\test\000007.jpg: 640x480 1 vest, 1119.4ms
# image 8/62629 D:\Skripsi\dataset\images\test\000008.jpg: 640x448 1 short sleeve top, 1 trousers, 1056.6ms
# image 9/62629 D:\Skripsi\dataset\images\test\000009.jpg: 640x480 1 short sleeve top, 1067.1ms
# image 10/62629 D:\Skripsi\dataset\images\test\000010.jpg: 480x640 1 vest, 1 skirt, 1329.4ms
# image 11/62629 D:\Skripsi\dataset\images\test\000011.jpg: 640x480 1 short sleeve top, 1131.5ms
# image 12/62629 D:\Skripsi\dataset\images\test\000012.jpg: 640x480 1 short sleeve top, 1 trousers, 995.3ms
# image 13/62629 D:\Skripsi\dataset\images\test\000013.jpg: 640x480 1 trousers, 1013.2ms
# image 14/62629 D:\Skripsi\dataset\images\test\000014.jpg: 640x480 1 short sleeve top, 1 vest dress, 1 sling dress, 1040.7ms
# image 15/62629 D:\Skripsi\dataset\images\test\000015.jpg: 640x480 1 vest dress, 1112.6ms
# image 16/62629 D:\Skripsi\dataset\images\test\000016.jpg: 640x384 1 short sleeve top, 1 shorts, 2 trouserss, 1108.2ms
# image 17/62629 D:\Skripsi\dataset\images\test\000017.jpg: 640x384 1 short sleeve top, 1 shorts, 1128.9ms
# image 18/62629 D:\Skripsi\dataset\images\test\000018.jpg: 640x480 1 long sleeve outwear, 1277.8ms
# image 19/62629 D:\Skripsi\dataset\images\test\000019.jpg: 640x480 1 short sleeve top, 1 vest dress, 1198.5ms
# image 20/62629 D:\Skripsi\dataset\images\test\000020.jpg: 640x480 1 short sleeve top, 1 vest dress, 1 sling dress, 1065.6ms
# image 21/62629 D:\Skripsi\dataset\images\test\000021.jpg: 640x384 1 short sleeve top, 1 shorts, 1026.8ms
# image 75/62629 D:\Skripsi\dataset\images\test\000075.jpg: 640x384 1 short sleeve top, 963.5ms
# image 76/62629 D:\Skripsi\dataset\images\test\000076.jpg: 640x480 1 long sleeve outwear, 1 trousers, 978.0ms
# image 77/62629 D:\Skripsi\dataset\images\test\000077.jpg: 640x288 1 long sleeve outwear, 691.8ms
# image 78/62629 D:\Skripsi\dataset\images\test\000078.jpg: 640x384 1 short sleeve top, 1 vest dress, 754.3ms
# image 79/62629 D:\Skripsi\dataset\images\test\000079.jpg: 384x640 (no detections), 875.3ms
# image 80/62629 D:\Skripsi\dataset\images\test\000080.jpg: 640x640 2 short sleeve tops, 1583.5ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       8 results = model.predict(source, stream=True, augment=True)
#      10 # Process results list
# ---> 11 for result in results:
#      12     boxes = result.boxes  # Boxes object for bbox outputs
#      13     masks = result.masks  # Masks object for segmentation masks outputs
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\utils\_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\predictor.py:259, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     257 # Inference
#     258 with profilers[1]:
# --> 259     preds = self.inference(im, *args, **kwargs)
#     261 # Postprocess
#     262 with profilers[2]:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\predictor.py:135, in BasePredictor.inference(self, im, *args, **kwargs)
#     132 """Runs inference on a given image using the specified model and arguments."""
#     133 visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     134                            mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 135 return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\autobackend.py:347, in AutoBackend.forward(self, im, augment, visualize)
#     344     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     346 if self.pt or self.nn_module:  # PyTorch
# --> 347     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     348 elif self.jit:  # TorchScript
#     349     y = self.model(im)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:42, in BaseModel.forward(self, x, *args, **kwargs)
#      40 if isinstance(x, dict):  # for cases of training and validating while training.
#      41     return self.loss(x, *args, **kwargs)
# ---> 42 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:58, in BaseModel.predict(self, x, profile, visualize, augment)
#      45 """
#      46 Perform a forward pass through the network.
#      47
#    (...)
#      55     (torch.Tensor): The last output of the model.
#      56 """
#      57 if augment:
# ---> 58     return self._predict_augment(x)
#      59 return self._predict_once(x, profile, visualize)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:262, in DetectionModel._predict_augment(self, x)
#     260 for si, fi in zip(s, f):
#     261     xi = scale_img(x.flip(fi) if fi else x, si, gs=int(self.stride.max()))
# --> 262     yi = super().predict(xi)[0]  # forward
#     263     yi = self._descale_pred(yi, fi, si, img_size)
#     264     y.append(yi)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:59, in BaseModel.predict(self, x, profile, visualize, augment)
#      57 if augment:
#      58     return self._predict_augment(x)
# ---> 59 return self._predict_once(x, profile, visualize)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\tasks.py:79, in BaseModel._predict_once(self, x, profile, visualize)
#      77 if profile:
#      78     self._profile_one_layer(m, x, dt)
# ---> 79 x = m(x)  # run
#      80 y.append(x if m.i in self.save else None)  # save output
#      81 if visualize:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\modules\head.py:46, in Detect.forward(self, x)
#      44 shape = x[0].shape  # BCHW
#      45 for i in range(self.nl):
# ---> 46     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      47 if self.training:
#      48     return x
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\nn\modules\conv.py:40, in Conv.forward_fuse(self, x)
#      38 def forward_fuse(self, x):
#      39     """Perform transposed convolution of 2D data."""
# ---> 40     return self.act(self.conv(x))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
